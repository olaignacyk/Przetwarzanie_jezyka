# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /opt/anaconda3/lib/python3.11/site-packages (3.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (8.3.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /opt/anaconda3/lib/python3.11/site-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /opt/anaconda3/lib/python3.11/site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<1.1.0,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.0->spacy) (1.0.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from thinc<8.4.0,>=8.3.0->spacy) (0.1.5)
# Collecting numpy>=1.19.0 (from spacy)
#   Using cached numpy-2.0.2-cp311-cp311-macosx_14_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.3.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in /opt/anaconda3/lib/python3.11/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Using cached numpy-2.0.2-cp311-cp311-macosx_14_0_arm64.whl (5.3 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# scipy 1.11.4 requires numpy<1.28.0,>=1.21.6, but you have numpy 2.0.2 which is incompatible.
# streamlit 1.30.0 requires numpy<2,>=1.19.3, but you have numpy 2.0.2 which is incompatible.
# pandas 2.1.4 requires numpy<2,>=1.23.2; python_version == "3.11", but you have numpy 2.0.2 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.0.2 which is incompatible.
# matplotlib 3.8.0 requires numpy<2,>=1.21, but you have numpy 2.0.2 which is incompatible.
# llama-index-core 0.11.14 requires numpy<2.0.0, but you have numpy 2.0.2 which is incompatible.
# tensorflow 2.16.1 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.0.2 which is incompatible.
# astropy 5.3.4 requires numpy<2,>=1.21, but you have numpy 2.0.2 which is incompatible.
# numba 0.59.0 requires numpy<1.27,>=1.22, but you have numpy 2.0.2 which is incompatible.
# pywavelets 1.5.0 requires numpy<2.0,>=1.22.4, but you have numpy 2.0.2 which is incompatible.
# Successfully installed numpy-2.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from spacy.cli import download

# %%
import requests
from bs4 import BeautifulSoup
from collections import Counter
import numpy as np
import re
import json
import networkx as nx
import csv

# %%
download("en_core_web_sm")
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 7.5 MB/s eta 0:00:0000:0100:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import requests
import json
import re
from bs4 import BeautifulSoup
from collections import defaultdict, Counter
import spacy

nlp = spacy.load("en_core_web_sm")

def get_page_content(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        paragraphs = soup.find_all('p')
        text = ' '.join([p.get_text() for p in paragraphs])
        return text
    return ""
    
def preprocess_text(text):
    text = re.sub(r'\d+', '', text) 
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    return text.lower().split(".") 

# Pobieranie 20 artykułów z Wikipedii na podstawie zapytania
language_code = 'en'
search_query = 'the'  # Wyszukujemy artykuły z najbardziej ogólnym zapytaniem
number_of_results = 20
headers = {
    'User-Agent': 'YOUR_APP_NAME (YOUR_EMAIL_OR_CONTACT_PAGE)'  # Ustaw odpowiednie nagłówki
}

base_url = 'https://api.wikimedia.org/core/v1/wikipedia/'
endpoint = '/search/page'
url = base_url + language_code + endpoint

parameters = {'q': search_query, 'limit': number_of_results}

response = requests.get(url, headers=headers, params=parameters)

response = json.loads(response.text)

urls = []
for page in response['pages']:
    article_url = 'https://' + language_code + '.wikipedia.org/wiki/' + page['key']
    urls.append(article_url)

sentences = []
for url in urls:
    text = get_page_content(url)
    if text:  
        words = preprocess_text(text)
        sentences.extend(words)

# %%
import spacy
from collections import defaultdict

nlp = spacy.load("en_core_web_sm")

transitive_verbs = most_common_verbs

verb_noun_dict = defaultdict(set)

for sentence in sentences:
    doc = nlp(sentence)
    for token in doc:
        if token.lemma_ in transitive_verbs and token.pos_ == "VERB":
            for child in token.children:
                if child.dep_ == "dobj" and child.pos_ == "NOUN":
                    verb_noun_dict[token.lemma_].add(child.lemma_)

for verb, nouns in verb_noun_dict.items():
    print(f"Czasownik: {verb} -> Rzeczowniki: {nouns}")
    print("____________________________________________________")
    
print("____________________________________________________")
print("Przykłady działań na zbiorach")
sum_have_include = verb_noun_dict["have"].union(verb_noun_dict["include"])
print(f"Suma have + include: {sum_have_include}")
print("____________________________________________________")
intersection_make_use = verb_noun_dict["make"].intersection(verb_noun_dict["use"])
print(f"Iloczyn make ∩ use: {intersection_make_use}")
print("____________________________________________________")
difference_follow_have = verb_noun_dict["follow"].difference(verb_noun_dict["have"])
print(f"Różnica follow - have: {difference_follow_have}")
print("____________________________________________________")
sum_eat_drink = verb_noun_dict["eat"].union(verb_noun_dict["drink"])
print(f"Suma eat + drink: {sum_eat_drink}")
# Out:
# Czasownik: have -> Rzeczowniki: {'history', 'meaning', 'time', 'mountain', 'article', 'story', 'office', 'choice', 'tooth', 'sound', 'charge', 'director', 'tilt', 'need', 'period', 'sense', 'characteristic', 'sequence', 'single', 'shirt', 'hand', 'selfrestraint', 'sex', 'character', 'bath', 'officer', 'bay', 'right', 'life', 'impulse', 'involvement', 'counterpart', 'side', 'explanation', 'panel', 'cousin', 'contingent', 'stroke', 'representative', 'relation', 'badge', 'delegate', 'leave', 'denslow', 'series', 'website', 'power', 'loss', 'grievance', 'quality', 'reprise', 'advantage', 'tendency', 'employee', 'subscriber', 'cartwright', 'rest', 'governor', 'immunity', 'tape', 'crossover', 'control', 'worth', 'people', 'printing', 'embassy', 'heir', 'ambition', 'attitude', 'city', 'newcomer', 'love', 'option', 'charisma', 'head', 'nightmare', 'part', 'relationship', 'backdoor', 'admiration', 'laurel', 'regret', 'eurydice', 'responsibility', 'acuman', 'casualty', 'task', 'infrastructure', 'partnering', 'issue', 'signatory', 'archive', 'baby', 'number', 'rerelease', 'camera', 'curtain', 'mccartney', 'rating', 'server', 'effect', 'trade', 'motive', 'alexander', 'composition', 'lunch', 'disagreement', 'interest', 'course', 'prince', 'slum', 'appeal', 'legislature', 'distinction', 'reputation', 'circulation', 'element', 'swift', 'feeling', 'deal', 'atmosphere', 'temper', 'bias', 'world', 'hairline', 'work', 'discussion', 'man', 'act', 'presence', 'ring', 'count', 'agreement', 'section', 'vulnerability', 'law', 'programme', 'version', 'idea', 'dropoff', 'expectation', 'surface', 'connection', 'population', 'torrent', 'form', 'slavery', 'link', 'movement', 'impact', 'scene', 'origin', 'album', 'trouble', 'slate', 'desire', 'coastline', 'wealth', 'block', 'value', 'opportunity', 'visitor', 'drop', 'engagement', 'skill', 'suspicion', 'crush', 'birthday', 'request', 'constitution', 'career', 'illustration', 'cable', 'ability', 'clause', 'record', 'line', 'billionaire', 'access', 'microphone', 'misconception', 'approval', 'statue', 'fun', 'redesign', 'bart', 'arsenal', 'experience'}
# ____________________________________________________
# Czasownik: take -> Rzeczowniki: {'break', 'merger', 'pippin', 'alexander', 'money', 'word', 'approach', 'site', 'schrute', 'control', 'office', 'residence', 'president', 'shortcut', 'bet', 'toto', 'possession', 'oath', 'trip', 'troop', 'position', 'image', 'photo', 'fight', 'guidance', 'home', 'charge', 'step', 'metadata', 'path', 'month', 'part', 'care', 'share', 'look', 'tablet', 'cover', 'ring', 'life', 'task', 'revenge', 'business', 'project', 'spot', 'notice', 'title', 'role', 'hold', 'issue', 'burst', 'chance', 'place', 'hour', 'year', 'leave', 'watt', 'benefit', 'show', 'note', 'power', 'summon', 'advantage', 'breath', 'post', 'effect'}
# ____________________________________________________
# Czasownik: write -> Rzeczowniki: {'history', 'alexander', 'article', 'word', 'story', 'thing', 'review', 'fantasy', 'prince', 'poem', 'book', 'account', 'part', 'headline', 'decade', 'line', 'legislation', 'role', 'version', 'letter', 'kind', 'blog', 'order', 'content', 'making', 'stylebook', 'contemporary', 'name', 'song', 'guide', 'note', 'sequel', 'wizard', 'episode', 'material', 'response', 'dialogue'}
# ____________________________________________________
# Czasownik: play -> Rzeczowniki: {'trio', 'prank', 'scarecrow', 'music', 'desire', 'villainess', 'snippet', 'journalist', 'fable', 'reputation', 'fight', 'top', 'spin', 'concert', 'character', 'copy', 'bass', 'munchkin', 'club', 'girl', 'rock', 'marvel', 'role', 'version', 'match', 'bottle', 'carol', 'swing', 'track', 'song', 'majority', 'ultimatum', 'show', 'night', 'berry', 'material', 'solo', 'instrument', 'bit', 'coroner'}
# ____________________________________________________
# Czasownik: establish -> Rzeczowniki: {'newsletter', 'canon', 'force', 'office', 'stake', 'beatle', 'partnership', 'system', 'union', 'arm', 'subordination', 'relationship', 'copyright', 'character', 'branch', 'question', 'norm', 'term', 'precedent', 'company', 'recommendation', 'committee', 'alliance', 'website', 'show', 'newspaper', 'server', 'pattern'}
# ____________________________________________________
# Czasownik: include -> Rzeczowniki: {'time', 'taxman', 'child', 'performance', 'flashpoint', 'sculpture', 'protester', 'wilde', 'introduction', 'film', 'rock', 'scale', 'stereo', 'actor', 'song', 'lyric', 'watt', 'string', 'sketch', 'individual', 'people', 'quotation', 'release', 'feature', 'newcomer', 'information', 'rage', 'concert', 'figure', 'meme', 'responsibility', 'mirror', 'podcast', 'archive', 'republic', 'doom', 'array', 'runway', 'hat', 'humor', 'citystate', 'alexander', 'download', 'composition', 'allusion', 'diffusion', 'doughnut', 'execution', 'inscription', 'novel', 'element', 'work', 'act', 'game', 'criticism', 'section', 'version', 'land', 'sale', 'track', 'simpson', 'scene', 'usage', 'picture', 'overdub', 'woman', 'drift', 'masthead', 'variety', 'press', 'nyt', 'illustration', 'accident', 'observer', 'clause', 'billionaire', 'user', 'death', 'resolution', 'debut', 'verse'}
# ____________________________________________________
# Czasownik: appoint -> Rzeczowniki: {'soninlaw', 'ambassador', 'army', 'son', 'sulzberger', 'scarecrow', 'member', 'officer', 'porus', 'dryfoo'}
# ____________________________________________________
# Czasownik: receive -> Rzeczowniki: {'type', 'credit', 'rate', 'alexander', 'acknowledgment', 'promotion', 'album', 'plurality', 'call', 'vote', 'review', 'citation', 'friedman', 'reception', 'airplay', 'cash', 'opportunity', 'ambassador', 'information', 'assistance', 'appearance', 'advice', 'award', 'share', 'score', 'hundred', 'criticism', 'support', 'recognition', 'pension', 'musician', 'fine', 'traffic', 'protection', 'wound', 'acclaim', 'analysis', 'widower', 'registration', 'status', 'advance', 'access', 'financing', 'nomination', 'letter', 'order', 'accolade', 'point', 'code', 'billing', 'boost', 'sentence', 'majority', 'news', 'complaint', 'prize', 'writing', 'rating'}
# ____________________________________________________
# Czasownik: make -> Rzeczowniki: {'inhouse', 'impact', 'profit', 'season', 'offer', 'money', 'joke', 'album', 'office', 'music', 'trip', 'arrangement', 'use', 'way', 'reference', 'baum', 'protagonist', 'no', 'top', 'sense', 'arm', 'online', 'sequence', 'showing', 'recipient', 'appearance', 'sacrifice', 'character', 'body', 'work', 'hundred', 'effort', 'impression', 'list', 'munchkin', 'appointment', 'influence', 'film', 'nod', 'lot', 'preparation', 'shape', 'material', 'record', 'statement', 'hostility', 'advance', 'nomination', 'attempt', 'version', 'writer', 'team', 'debut', 'recommendation', 'bid', 'family', 'war', 'number', 'designation', 'arrhidaeus', 'cost', 'intermediary', 'announcement', 'mistake', 'light', 'comment', 'determination', 'loss', 'member', 'tour', 'episode', 'contribution', 'nominee'}
# ____________________________________________________
# Czasownik: serve -> Rzeczowniki: {'term', 'truman', 'allegory', 'presidency', 'personnel', 'year', 'sentence', 'month', 'screen', 'sauron', 'quaestorship', 'role'}
# ____________________________________________________
# Czasownik: begin -> Rzeczowniki: {'celebration', 'history', 'production', 'negotiation', 'guitarist', 'study', 'reign', 'performance', 'music', 'process', 'beatle', 'campaign', 'relationship', 'character', 'comeback', 'work', 'session', 'effort', 'career', 'push', 'law', 'progression', 'war', 'series', 'tour', 'journey', 'string'}
# ____________________________________________________
# Czasownik: elect -> Rzeczowniki: {'economy', 'percent', 'president', 'senator'}
# ____________________________________________________
# Czasownik: lead -> Rzeczowniki: {'producer', 'rest', 'people', 'nation', 'troop', 'campaign', 'charge', 'league', 'work', 'dwight', 'investigation', 'man', 'branch', 'effort', 'opposition', 'drummer', 'magazine', 'victim', 'scholar', 'presidency', 'bracelet', 'delegate', 'army', 'lane', 'network', 'party', 'historian'}
# ____________________________________________________
# Czasownik: offer -> Rzeczowniki: {'revision', 'service', 'job', 'story', 'exception', 'beatle', 'collection', 'subsidy', 'deal', 'work', 'treaty', 'variety', 'ring', 'term', 'pension', 'daughter', 'club', 'saruman', 'analysis', 'subscription', 'podcast', 'chance', 'file', 'alternative', 'benefit', 'news', 'detail', 'show', 'cause', 'link'}
# ____________________________________________________
# Czasownik: send -> Rzeczowniki: {'offer', 'tape', 'engineer', 'embassy', 'convention', 'veteran', 'pack', 'chapter', 'work', 'warg', 'andromene', 'scout', 'flock', 'record', 'thessalus', 'monkey', 'bulk', 'sum', 'message', 'delegate', 'dozen', 'army', 'insect'}
# ____________________________________________________
# Czasownik: bring -> Rzeczowniki: {'credit', 'harrison', 'connotation', 'kronor', 'mine', 'reward', 'exposure', 'release', 'lead', 'gleam', 'element', 'government', 'character', 'copy', 'income', 'subscription', 'date', 'prosecution', 'horse', 'thessalus', 'bottle', 'order', 'bill', 'chomet', 'number', 'mind', 'animator', 'army', 'show', 'experience', 'tour', 'episode', 'broomstick'}
# ____________________________________________________
# Czasownik: win -> Rzeczowniki: {'battle', 'slot', 'vote', 'election', 'flannery', 'favour', 'award', 'manager', 'film', 'state', 'programme', 'contest', 'reelection', 'accolade', 'erin', 'range', 'presidency', 'category', 'reader', 'victory', 'majority', 'song', 'dozen', 'prize', 'affection', 'total'}
# ____________________________________________________
# Czasownik: hold -> Rzeczowniki: {'break', 'marriage', 'swath', 'service', 'office', 'devotion', 'nation', 'president', 'gift', 'stake', 'danger', 'banquet', 'position', 'honour', 'hand', 'deal', 'scalpel', 'session', 'share', 'speech', 'right', 'record', 'spot', 'diary', 'meeting', 'percent', 'antipalestinian', 'investment', 'port', 'orb', 'presidency', 'edition', 'light', 'series', 'custom', 'wizard', 'strike'}
# ____________________________________________________
# Czasownik: lose -> Rzeczowniki: {'eye', 'battle', 'alexander', 'votef', 'interest', 'child', 'contact', 'wealth', 'day', 'appearance', 'streak', 'man', 'support', 'theban', 'right', 'audience', 'life', 'title', 'elasticity', 'generation', 'footing', 'power', 'patience'}
# ____________________________________________________
# Czasownik: change -> Rzeczowniki: {'seal', 'perception', 'music', 'model', 'way', 'move', 'period', 'system', 'domain', 'appearance', 'masthead', 'artist', 'rank', 'inconsistency', 'shape', 'title', 'opinion', 'order', 'critic', 'mind', 'name', 'dorothy', 'homepage', 'lyric', 'series', 'salute', 'writing'}
# ____________________________________________________
# Czasownik: increase -> Rzeczowniki: {'guild', 'fine', 'size', 'capacity', 'interest', 'fortune', 'power', 'percent', 'salary', 'security', 'contact', 'popularity', 'effort'}
# ____________________________________________________
# Czasownik: grow -> Rzeczowniki: {'economy', 'opportunity'}
# ____________________________________________________
# Czasownik: use -> Rzeczowniki: {'center', 'chiffon', 'treasure', 'attack', 'crowd', 'article', 'oscillator', 'ink', 'mbone', 'tesseract', 'chapel', 'procedure', 'datum', 'ram', 'character', 'headline', 'ptolemy', 'format', 'stage', 'tone', 'panel', 'superlative', 'amplifier', 'horn', 'ship', 'flashback', 'order', 'phrase', 'song', 'firebase', 'power', 'string', 'wall', 'tuning', 'instrument', 'technology', 'technique', 'menace', 'thrower', 'ratio', 'staplesbranded', 'map', 'gift', 'estimate', 'initial', 'setup', 'technicolor', 'part', 'figure', 'opene', 'tool', 'term', 'memo', 'gdal', 'analysis', 'routine', 'slipper', 'drummer', 'spellwound', 'letter', 'studio', 'hose', 'player', 'name', 'broadcast', 'member', 'car', 'server', 'predecessor', 'alexander', 'jagger', 'word', 'store', 'equipment', 'process', 'knight', 'authority', 'element', 'cloth', 'system', 'language', 'jackson', 'flurry', 'score', 'game', 'mambo', 'recorder', 'style', 'honorific', 'club', 'bomb', 'catchphrase', 'plant', 'version', 'idea', 'operation', 'sarissa', 'content', 'footage', 'track', 'personnel', 'privilege', 'speed', 'heroin', 'price', 'assortment', 'service', 'device', 'use', 'image', 'model', 'leaflet', 'accent', 'block', 'domain', 'testing', 'deployment', 'talent', 'source', 'title', 'prevail', 'timeline', 'discomfort'}
# ____________________________________________________
# Czasownik: give -> Rzeczowniki: {'credit', 'ending', 'contract', 'reason', 'alexander', 'preference', 'tape', 'job', 'control', 'instruction', 'choice', 'stone', 'focus', 'performance', 'gift', 'estimate', 'office', 'play', 'position', 'example', 'heart', 'regard', 'exbeatle', 'opportunity', 'account', 'copyright', 'part', 'era', 'birth', 'advice', 'level', 'copy', 'grade', 'briant', 'tablet', 'impression', 'payment', 'shoe', 'protection', 'sing', 'entre', 'rotation', 'permission', 'notice', 'personality', 'fellowship', 'role', 'letter', 'brain', 'token', 'solidity', 'confidence', 'chance', 'increase', 'praise', 'rise', 'successor', 'year', 'name', 'rein', 'song', 'cloak', 'majority', 'post', 'sword', 'show', 'power', 'injunction', 'broomstick', 'package', 'coherence', 'knowledge', 'goggle'}
# ____________________________________________________
# Czasownik: introduce -> Rzeczowniki: {'employee', 'coinage', 'stone', 'beatle', 'model', 'draft', 'feature', 'snag', 'character', 'game', 'nyt', 'change', 'paywall', 'digit', 'proskynesis', 'legislation', 'title', 'video', 'website'}
# ____________________________________________________
# Czasownik: ask -> Rzeczowniki: {'diogene', 'dwight', 'reader', 'liga', 'alexander', 'captain', 'wizard', 'senator', 'aslam', 'woodman', 'question', 'pam'}
# ____________________________________________________
# Czasownik: issue -> Rzeczowniki: {'type', 'compilation', 'appeal', 'capitol', 'antiendorsement', 'apology', 'correction', 'song', 'protest', 'warrant', 'resolution', 'recording', 'music', 'release', 'regulation', 'stamp'}
# ____________________________________________________
# Czasownik: call -> Rzeczowniki: {'israel', 'trilogy', 'album', 'stone', 'performer', 'demand', 'helpline', 'tolkien', 'engagement', 'congress', 'session', 'caesar', 'father', 'state', 'video', 'bombadil', 'show', 'one', 'simpson', 'band'}
# ____________________________________________________
# Czasownik: confirm -> Rzeczowniki: {'death', 'date', 'nomination', 'episode'}
# ____________________________________________________
# Czasownik: remove -> Rzeczowniki: {'reference', 'memo', 'ringleader', 'request', 'bay', 'element', 'kingdom', 'dress', 'makeup', 'claim', 'link', 'torrent', 'coat', 'joke', 'official', 'attlee'}
# ____________________________________________________
# Czasownik: provide -> Rzeczowniki: {'history', 'concertgoer', 'individual', 'service', 'editor', 'shot', 'scarecrow', 'president', 'voice', 'connectivity', 'commentary', 'element', 'swift', 'opportunity', 'support', 'lot', 'check', 'feedback', 'access', 'security', 'challenge', 'grant', 'increase', 'range', 'obstacle', 'temple', 'detail', 'spouse'}
# ____________________________________________________
# Czasownik: get -> Rzeczowniki: {'credit', 'season', 'album', 'job', 'performance', 'estimate', 'satisfaction', 'review', 'feeling', 'cent', 'sense', 'hand', 'declaration', 'world', 'royalty', 'film', 'revenge', 'offscreen', 'hold', 'yayas', 'lyric', 'back', 'ticket'}
# ____________________________________________________
# Czasownik: involve -> Rzeczowniki: {'case', 'farmer', 'family', 'file', 'mermaid', 'solicitor', 'vehicle', 'action', 'script', 'tag', 'character', 'choir', 'role', 'president', 'witch', 'deck', 'proceeding', 'band'}
# ____________________________________________________
# Czasownik: leave -> Rzeczowniki: {'portion', 'time', 'storm', 'production', 'lineup', 'bandmate', 'guardian', 'alexander', 'paper', 'stone', 'office', 'worker', 'nation', 'position', 'collection', 'move', 'netflix', 'example', 'government', 'month', 'cast', 'leader', 'neverland', 'branch', 'ring', 'classroom', 'stage', 'project', 'line', 'spot', 'title', 'group', 'house', 'gap', 'message', 'edition', 'detail', 'series', 'show', 'richard', 'wizard', 'blue', 'band'}
# ____________________________________________________
# Czasownik: claim -> Rzeczowniki: {'privilege', 'billionaire', 'power', 'performer', 'authorship', 'position'}
# ____________________________________________________
# Czasownik: create -> Rzeczowniki: {'interface', 'painting', 'individual', 'story', 'recording', 'music', 'sound', 'wealth', 'masterpiece', 'quiz', 'illusion', 'logo', 'problem', 'character', 'work', 'imbroglio', 'hairstyle', 'copy', 'tune', 'look', 'man', 'game', 'precedent', 'ring', 'decoration', 'publishing', 'pension', 'extension', 'audience', 'style', 'repository', 'nameplate', 'codeword', 'state', 'realism', 'studio', 'order', 'family', 'culture', 'committee', 'series', 'show', 'structure', 'situation', 'wall', 'total', 'presentation'}
# ____________________________________________________
# Czasownik: turn -> Rzeczowniki: {'request', 'family', 'saruman', 'offer', 'stem', 'script', 'marching', 'part', 'evidence', 'treatment', 'tide', 'ornament'}
# ____________________________________________________
# Czasownik: release -> Rzeczowniki: {'folklore', 'article', 'ice', 'strand', 'people', 'album', 'stone', 'search', 'return', 'recording', 'music', 'legend', 'beatle', 'saga', 'catalogue', 'day', 'special', 'majesty', 'gold', 'lady', 'swift', 'application', 'book', 'information', 'hostage', 'thousand', 'tool', 'ep', 'work', 'grip', 'lick', 'game', 'cover', 'request', 'document', 'film', 'girl', 'vinyl', 'date', 'rescue', 'title', 'version', 'prequel', 'edition', 'song', 'goddess', 'wave', 'rooster', 'material', 'band'}
# ____________________________________________________
# Czasownik: cause -> Rzeczowniki: {'unrest', 'controversy', 'increase', 'candidate', 'fit', 'burn', 'suffering', 'complaint', 'queue', 'thousand', 'confusion', 'uproar', 'downtime', 'consternation', 'problem', 'outage', 'dismissal'}
# ____________________________________________________
# Czasownik: reach -> Rzeczowniki: {'merit', 'standard', 'alexander', 'mark', 'edge', 'city', 'band', 'greece', 'top', 'step', 'print', 'pathway', 'agreement', 'susa', 'digit', 'billionaire', 'spot', 'mina', 'version', 'age', 'territory', 'number', 'village', 'end', 'episode', 'customer'}
# ____________________________________________________
# Czasownik: refer -> Rzeczowniki: {'appearance', 'trump'}
# ____________________________________________________
# Czasownik: start -> Rzeczowniki: {'reemerge', 'guardianfilm', 'marathon', 'company', 'fire', 'investigation', 'commune', 'success', 'tradition', 'podcast', 'cover', 'hobbit'}
# ____________________________________________________
# Czasownik: open -> Rzeczowniki: {'set', 'eye', 'fire', 'album', 'door', 'theme', 'day', 'concert', 'act', 'branch', 'rank', 'newsroom', 'rock', 'company', 'access', 'centre', 'tower', 'show', 'boutique', 'tour', 'box'}
# ____________________________________________________
# Czasownik: live -> Rzeczowniki: {'album', 'rest'}
# ____________________________________________________
# Czasownik: describe -> Rzeczowniki: {'time', 'beatle', 'demand', 'theme', 'color', 'jaggerrichard', 'swift', 'ego', 'relationship', 'era', 'concert', 'work', 'area', 'session', 'enthusiasm', 'bay', 'contest', 'evolution', 'death', 'event', 'extravaganza', 'batch', 'presidency', 'admission', 'apple', 'heroism', 'king', 'mccartney', 'announcement', 'lp', 'boundary', 'show', 'experience', 'tour', 'parody', 'party'}
# ____________________________________________________
# Czasownik: set -> Rzeczowniki: {'bang', 'fire', 'justification', 'bar', 'animosity', 'collection', 'page', 'poem', 'example', 'flick', 'precedent', 'press', 'room', 'film', 'qualification', 'record', 'date', 'blog', 'show', 'ticket', 'structure'}
# ____________________________________________________
# Czasownik: meet -> Rzeczowniki: {'lennon', 'guardian', 'jagger', 'alexander', 'people', 'scarecrow', 'merry', 'parent', 'legend', 'beatle', 'demand', 'lion', 'gandalf', 'strider', 'qualification', 'elf', 'criterion', 'tip', 'death', 'friend', 'expectation', 'ranger', 'richard', 'member', 'wizard', 'simpson'}
# ____________________________________________________
# Czasownik: follow -> Rzeczowniki: {'battle', 'alexander', 'interest', 'greek', 'success', 'course', 'release', 'move', 'home', 'resignation', 'shooting', 'tolkien', 'cancellation', 'campbell', 'panic', 'flame', 'closure', 'road', 'problem', 'suit', 'format', 'agreement', 'state', 'cleopatra', 'relocation', 'death', 'order', 'conquest', 'dorothy', 'departure', 'lockdown', 'member', 'telecast', 'report', 'scandal'}
# ____________________________________________________
# Czasownik: support -> Rzeczowniki: {'movement', 't', 'trade', 'guardian', 'article', 'alexander', 'editing', 'site', 'worker', 'nation', 'government', 'tracker', 'part', 'cooper', 'character', 'confederacy', 'intervention', 'bay', 'right', 'tribunal', 'legislation', 'encryption', 'regime', 'medium', 'actor', 'jet', 'commitment', 'link', 'decision', 'parent', 'negativism'}
# ____________________________________________________
# Czasownik: break -> Rzeczowniki: {'center', 'outbreak', 'alexander', 'jagger', 'law', 'record', 'barrier', 'lewis', 'news', 'line', 'phalanx', 'meeting', 'power', 'episode', 'string', 'butterfly', 'wall', 'precedent'}
# ____________________________________________________
# Czasownik: die -> Rzeczowniki: {'darius', 'day', 'king', 'city'}
# ____________________________________________________
# Czasownik: decide -> Rzeczowniki: {'rendition', 'section'}
# ____________________________________________________
# Czasownik: report -> Rzeczowniki: {'licence', 'harrison', 'article', 'story', 'demand', 'malware', 'ebitda', 'reach', 'thousand', 'royalty', 'effort', 'question', 'similarity', 'scalping', 'increase', 'number', 'shock', 'loss', 'package'}
# ____________________________________________________
# Czasownik: announce -> Rzeczowniki: {'boxscore', 'time', 'variant', 'release', 'partnership', 'promise', 'resignation', 'application', 'gross', 'nyt', 'leg', 'publication', 'version', 'let', 'intention', 'year', 'pledge', 'show', 'departure', 'tour', 'plan'}
# ____________________________________________________
# Czasownik: contain -> Rzeczowniki: {'thought', 'save', 'alexander', 'article', 'lesson', 'story', 'minute', 'explosive', 'correction', 'lothlrien', 'reference', 'feature', 'sign', 'newspaper', 'selection', 'information', 'url', 'grave', 'work', 'powder', 'movie', 'bitch', 'angie', 'behindthescene', 'track', 'number', 'song', 'comment', 'total', 'documentary', 'row', 'link', 'plan'}
# ____________________________________________________
# Czasownik: join -> Rzeczowniki: {'guild', 'band', 'day', 'reception', 'partnership', 'list', 'trio', 'onstage', 'army', 'cast', 'stone', 'frodo', 'richard', 'party', 'group', 'son', 'session'}
# ____________________________________________________
# Czasownik: roll -> Rzeczowniki: {'stonefly', 'gold', 'element', 'stone', 'door'}
# ____________________________________________________
# Czasownik: develop -> Rzeczowniki: {'scene', 'park', 'site', 'interest', 'fever', 'recording', 'system', 'needle', 'tool', 'character', 'bond', 'game', 'crush', 'script', 'passion', 'song', 'series', 'website', 'show'}
# ____________________________________________________
# Czasownik: produce -> Rzeczowniki: {'lennon', 'article', 'people', 'album', 'heir', 'adaptation', 'recording', 'beatle', 'gag', 'newcomer', 'love', 'newspaper', 'book', 'evidence', 'game', 'film', 'section', 'stage', 'footballer', 'symptom', 'version', 'appendix', 'song', 'series', 'wizard', 'episode', 'uncle', 'material', 'report', 'simpson', 'effect'}
# ____________________________________________________
# Czasownik: sell -> Rzeczowniki: {'threequarter', 'service', 'interest', 'album', 'success', 'quarter', 'stadium', 'novel', 'gold', 'single', 'asset', 'figure', 'division', 'copy', 'product', 'share', 'platinum', 'bridge', 'right', 'business', 'unit', 'title', 'fourdvd', 'song', 'majority', 'ticket', 'tour', 'merchandise', 'package', 'band'}
# ____________________________________________________
# Czasownik: perform -> Rzeczowniki: {'lennon', 'attack', 'stunt', 'feat', 'antihero', 'none', 'system', 'part', 'gig', 'concert', 'shelter', 'man', 'list', 'style', 'change', 'version', 'surgery', 'track', 'number', 'behaviour', 'duty', 'song', 'dance', 'pilgrimage', 'cardigan', 'function', 'string', 'blue'}
# ____________________________________________________
# Czasownik: find -> Rzeczowniki: {'avenue', 'kingdom', 'appendix', 'ip', 'alexander', 'billionaire', 'makeup', 'subject', 'drummer', 'merry', 'success', 'stride', 'person', 'role', 'way'}
# ____________________________________________________
# Czasownik: tell -> Rzeczowniki: {'monkey', 'torrentfreak', 'register', 'reader', 'express', 'dorothy', 'alexander', 'hand', 'reuter', 'scarecrow', 'garland', 'story', 'episode', 'pixodarus', 'pam', 'writer'}
# ____________________________________________________
# Czasownik: place -> Rzeczowniki: {'ad', 'inauguration', 'order', 'america', 'reason', 'dangote', 'phalanx', 'hat', 'table', 'focus', 'headline', 'beatle', 'simpson', 'game'}
# ____________________________________________________
# Czasownik: feature -> Rzeczowniki: {'set', 'artwork', 'race', 'wyman', 'scene', 'time', 'coaster', 'employee', 'article', 'crossover', 'achievement', 'orchestra', 'stone', 'bed', 'voice', 'sympathy', 'beam', 'experimentation', 'woman', 'wiesel', 'use', 'city', 'rapace', 'move', 'page', 'photo', 'poem', 'toilet', 'recipe', 'appearance', 'cast', 'logo', 'interview', 'shelter', 'zipper', 'column', 'drawing', 'headline', 'man', 'cover', 'toolkit', 'style', 'visual', 'function', 'subcategorie', 'riff', 'interval', 'outtake', 'hair', 'version', 'death', 'horn', 'podcast', 'video', 'footage', 'track', 'clip', 'accompaniment', 'dice', 'number', 'song', 'category', 'subset', 'dozen', 'pixmob', 'news', 'array', 'show', 'netanyahu', 'episode', 'material', 'vision'}
# ____________________________________________________
# Czasownik: record -> Rzeczowniki: {'set', 'finger', 'site', 'album', 'sideman', 'single', 'information', 'work', 'session', 'tune', 'whole', 'casualty', 'record', 'riff', 'version', 'order', 'sale', 'track', 'number', 'song', 'lp', 'proceeding'}
# ____________________________________________________
# Czasownik: publish -> Rzeczowniki: {'newsletter', 'entirety', 'contract', 'article', 'paper', 'story', 'stone', 'claim', 'email', 'friedman', 'advert', 'draft', 'photo', 'novel', 'database', 'book', 'hall', 'recipe', 'result', 'figure', 'column', 'investigation', 'list', 'tweed', 'statement', 'key', 'fellowship', 'address', 'version', 'letter', 'piece', 'autobiography', 'content', 'file', 'number', 'edition', 'guide', 'cartoon', 'news', 'series', 'announcement', 'sequel', 'expletive', 'report'}
# ____________________________________________________
# Czasownik: show -> Rzeczowniki: {'palace', 'impact', 'time', 'subscriber', 'concertgoer', 'picture', 'performance', 'clock', 'intent', 'spark', 'swift', 'sense', 'sign', 'sequence', 'liking', 'selfcontrol', 'book', 'thousand', 'error', 'plutarch', 'manuscript', 'film', 'billionaire', 'piece', 'group', 'mercy', 'servicemen'}
# ____________________________________________________
# Czasownik: continue -> Rzeczowniki: {'quest', 'format', 'bridge', 'affair', 'lifestyle', 'west', 'relationship', 'division', 'programme', 'tour', 'investigation'}
# ____________________________________________________
# Czasownik: allow -> Rzeczowniki: {'monitoring', 'show', 'opinion', 'time'}
# ____________________________________________________
# Czasownik: return -> Rzeczowniki: {'mbe', 'insignia', 'ambhi', 'name', 'title', 'man'}
# ____________________________________________________
# Czasownik: see -> Rzeczowniki: {'pippin', 'picture', 'stone', 'traveler', 'return', 'coat', 'possession', 'release', 'need', 'half', 'tv', 'water', 'winner', 'launch', 'castle', 'future', 'toby', 'quest', 'footage', 'fate', 'number', 'light', 'episode', 'end', 'wizard', 'report', 'harmony'}
# ____________________________________________________
# Czasownik: do -> Rzeczowniki: {'set', 'critic', 'pickup', 'daughter', 'justice', 'step', 'record', 'soup', 'show', 'landmark', 'office', 'fleming', 'tour', 'opinion', 'performance', 'thing'}
# ____________________________________________________
# Czasownik: know -> Rzeczowniki: {'harrison', 'alexander', 'subscription', 'lyric', 'pink', 'rider', 'man'}
# ____________________________________________________
# Czasownik: want -> Rzeczowniki: {'sky', 'bump', 'heart', 'song', 'courage', 'peace', 'brain', 'bride'}
# ____________________________________________________
# Czasownik: consider -> Rzeczowniki: {'academic', 'offer', 'approach', 'part', 'publication', 'case', 'material'}
# ____________________________________________________
# Czasownik: end -> Rzeczowniki: {'pretence', 'credit', 'bay', 'infringement', 'accessory', 's', 'edition', 'grudge', 'run', 'line', 'relationship', 'series', 'crisis', 'sphinx', 'mysql', 'act'}
# ____________________________________________________
# Czasownik: add -> Rzeczowniki: {'sitar', 'emblem', 'dulcimer', 'single', 'characteristic', 'information', 'domain', 'part', 'precinct', 'demo', 'date', 'cavalry', 'vocal', 'track', 'edition', 'song', 'detail', 'show', 'joke'}
# ____________________________________________________
# Czasownik: name -> Rzeczowniki: {'city', 'film', 'stonefly', 'rock', 'series', 'album', 'stone', 'character', 'bucephala', 'death', 'baquet', 'simpson', 'band'}
# ____________________________________________________
# Czasownik: say -> Rzeczowniki: {'song', 'farewell', 'hail', 'marge', 'thing'}
# ____________________________________________________
# Czasownik: work -> Rzeczowniki: {'land', 'stage', 'position', 'alexander', 'deal', 'makeup', 'story', 'trash', 'hobbit'}
# ____________________________________________________
# Czasownik: kill -> Rzeczowniki: {'bay', 'spider', 'advocate', 'ukrainian', 'pippin', 'slave', 'people', 'project', 'thousand', 'soldier', 'balrog', 'servicemen', 'witch', 'music', 'symbol', 'civilian', 'man'}
# ____________________________________________________
# Czasownik: appear -> Rzeczowniki: {'note', 'censorship'}
# ____________________________________________________
# Czasownik: go -> Rzeczowniki: {'war', 'sixty', 'ticket', 'member', 'route', 'platinum'}
# ____________________________________________________
# Czasownik: wear -> Rzeczowniki: {'insignia', 'mantle', 'collar', 'pot', 'use', 'vestment', 'emblem', 'cape', 'suit', 'glove', 'style', 'wig', 'knightsdame', 'leotard', 'dress', 'version', 'disc', 'breastplate', 'badge', 'uniform', 'cap', 'star', 'headdress', 'spectacle', 'shoe', 'goggle'}
# ____________________________________________________
# Czasownik: run -> Rzeczowniki: {'recognition', 'server', 'season', 'article', 'project', 'website', 'fund', 'star', 'farm', 'contest', 'correction', 'editorial', 'groening', 'son', 'ad', 'list'}
# ____________________________________________________
# Czasownik: move -> Rzeczowniki: {'press', 'family', 'gantry', 'series', 'match', 'server', 'list'}
# ____________________________________________________
# Czasownik: estimate -> Rzeczowniki: {'gross', 'sale', 'site'}
# ____________________________________________________
# Czasownik: air -> Rzeczowniki: {'program', 'air', 'season', 'courtesy', 'sister', 'marathon', 'tour', 'rerun', 'documentary'}
# ____________________________________________________
# Czasownik: suggest -> Rzeczowniki: {'possibility', 'voting', 'midget'}
# ____________________________________________________
# Czasownik: think -> Rzeczowniki: {'picture', 'something'}
# ____________________________________________________
# Czasownik: animate -> Rzeczowniki: {'show', 'simpson'}
# ____________________________________________________
# Czasownik: come -> Rzeczowniki: {'science', 'election', 'number'}
# ____________________________________________________
# Czasownik: state -> Rzeczowniki: {'thank', 'problem', 'core', 'district'}
# ____________________________________________________
# Czasownik: need -> Rzeczowniki: {'direction', 'guitarist', 'help', 'light', 'couple', 'prop', 'group', 'firework', 'bit'}
# ____________________________________________________
# Czasownik: base -> Rzeczowniki: {'opposition'}
# ____________________________________________________
# Czasownik: become -> Rzeczowniki: {'casualty'}
# ____________________________________________________
# ____________________________________________________
# Przykłady działań na zbiorach
# Suma have + include: {'history', 'meaning', 'time', 'mountain', 'article', 'story', 'office', 'choice', 'tooth', 'taxman', 'child', 'sound', 'performance', 'flashpoint', 'sculpture', 'charge', 'director', 'tilt', 'need', 'period', 'sense', 'characteristic', 'sequence', 'single', 'shirt', 'hand', 'selfrestraint', 'sex', 'character', 'protester', 'bath', 'officer', 'wilde', 'bay', 'introduction', 'film', 'right', 'life', 'impulse', 'rock', 'involvement', 'counterpart', 'side', 'explanation', 'scale', 'panel', 'cousin', 'contingent', 'stroke', 'representative', 'relation', 'badge', 'stereo', 'delegate', 'actor', 'song', 'leave', 'lyric', 'denslow', 'series', 'website', 'watt', 'power', 'loss', 'grievance', 'quality', 'string', 'reprise', 'advantage', 'sketch', 'tendency', 'employee', 'subscriber', 'cartwright', 'rest', 'governor', 'immunity', 'tape', 'crossover', 'control', 'worth', 'people', 'printing', 'embassy', 'heir', 'ambition', 'quotation', 'attitude', 'release', 'city', 'individual', 'feature', 'newcomer', 'love', 'option', 'charisma', 'head', 'information', 'nightmare', 'part', 'relationship', 'backdoor', 'rage', 'concert', 'figure', 'admiration', 'laurel', 'regret', 'eurydice', 'meme', 'responsibility', 'acuman', 'casualty', 'mirror', 'task', 'infrastructure', 'partnering', 'issue', 'podcast', 'signatory', 'archive', 'baby', 'number', 'rerelease', 'camera', 'curtain', 'republic', 'doom', 'mccartney', 'array', 'runway', 'rating', 'hat', 'server', 'effect', 'humor', 'citystate', 'trade', 'motive', 'alexander', 'download', 'composition', 'lunch', 'disagreement', 'interest', 'course', 'allusion', 'diffusion', 'prince', 'slum', 'appeal', 'legislature', 'distinction', 'doughnut', 'execution', 'reputation', 'circulation', 'element', 'swift', 'feeling', 'inscription', 'novel', 'deal', 'atmosphere', 'temper', 'bias', 'world', 'hairline', 'work', 'discussion', 'man', 'act', 'game', 'presence', 'ring', 'count', 'criticism', 'agreement', 'section', 'vulnerability', 'law', 'programme', 'version', 'idea', 'land', 'dropoff', 'expectation', 'sale', 'surface', 'connection', 'track', 'population', 'torrent', 'form', 'slavery', 'link', 'simpson', 'movement', 'impact', 'scene', 'usage', 'origin', 'picture', 'album', 'overdub', 'woman', 'trouble', 'slate', 'drift', 'desire', 'coastline', 'wealth', 'block', 'value', 'opportunity', 'visitor', 'drop', 'engagement', 'masthead', 'skill', 'suspicion', 'variety', 'crush', 'birthday', 'request', 'constitution', 'press', 'career', 'nyt', 'illustration', 'cable', 'ability', 'clause', 'record', 'accident', 'line', 'billionaire', 'observer', 'user', 'access', 'microphone', 'misconception', 'death', 'approval', 'statue', 'fun', 'redesign', 'resolution', 'debut', 'bart', 'arsenal', 'experience', 'verse'}
# ____________________________________________________
# Iloczyn make ∩ use: {'version', 'character', 'member', 'use'}
# ____________________________________________________
# Różnica follow - have: {'battle', 'greek', 'success', 'release', 'move', 'home', 'resignation', 'shooting', 'tolkien', 'cancellation', 'campbell', 'panic', 'flame', 'closure', 'road', 'problem', 'suit', 'format', 'state', 'cleopatra', 'relocation', 'death', 'order', 'conquest', 'dorothy', 'departure', 'lockdown', 'member', 'telecast', 'report', 'scandal'}
# ____________________________________________________
# Suma eat + drink: set()
